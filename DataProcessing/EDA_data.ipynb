# %%
#import thu vien
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/binperdok/KLTN2026/Data/data_label_deepdive/data_deep_dive_2026_03_07_full_vietnamese.csv")

# %%
df.head(5)
# Out:
#            Source                                              Title  \
# 0  huggingface.co  PRX Part 3 — Training a Text-to-Image Model in...
# 1  huggingface.co          Mixture of Experts (MoEs) in Transformers
# 2  huggingface.co  Train AI models with Unsloth and Hugging Face ...
# 3  huggingface.co  Transformers.js v4 Preview: Now Available on NPM!
# 4  huggingface.co  H Company's new Holo2 model takes the lead in ...
#
#                                                 Link  \
# 0    https://huggingface.co/blog/Photoroom/prx-part3
# 1       https://huggingface.co/blog/moe-transformers
# 2           https://huggingface.co/blog/unsloth-jobs
# 3      https://huggingface.co/blog/transformersjs-v4
# 4  https://huggingface.co/blog/Hcompany/introduci...
#
#                             Date  \
# 0  Tue, 03 Mar 2026 16:50:49 GMT
# 1  Thu, 26 Feb 2026 00:00:00 GMT
# 2  Fri, 20 Feb 2026 00:00:00 GMT
# 3  Mon, 09 Feb 2026 00:00:00 GMT
# 4  Tue, 03 Feb 2026 17:40:14 GMT
#
# ...

# %%
# Ví dụ nếu tên cột chuẩn là:
df.drop(columns=['Source', 'Title', 'Link', 'Date', 'content'], inplace=True)

# %%
df.head()
# Out:
#                                             Title_VN  \
# 0  PRX Part 3 — Đào tạo một Text-to-Image Model t...
# 1       Mixture of Experts (MoEs) trong Transformers
# 2  Huấn luyện các mô hình AI với Unsloth và Huggi...
# 3  Transformers.js v4 Preview: Hiện đã có mặt trê...
# 4  Mô hình Holo2 mới của Công ty H dẫn đầu trong ...
#
#                                           content_VN
# 0  Chào mừng trở lại 👋 Trong hai bài viết trước (...
# 1  Trong vài năm qua, việc mở rộng quy mô các mô ...
# 2  Bạn sẽ cầnChạy JobCài đặt SkillClaude CodeCode...
# 3  Cải thiện Hiệu suất & Thời gian chạy\nTái cấu ...
# 4  Hai tháng kể từ khi phát hành đợt đầu tiên của...

# %%
df.rename(columns = {"Title_VN" : "Title", "content_VN": "content"}, inplace = True )

# %%
df.head(5)
# Out:
#                                                Title  \
# 0  PRX Part 3 — Đào tạo một Text-to-Image Model t...
# 1       Mixture of Experts (MoEs) trong Transformers
# 2  Huấn luyện các mô hình AI với Unsloth và Huggi...
# 3  Transformers.js v4 Preview: Hiện đã có mặt trê...
# 4  Mô hình Holo2 mới của Công ty H dẫn đầu trong ...
#
#                                              content
# 0  Chào mừng trở lại 👋 Trong hai bài viết trước (...
# 1  Trong vài năm qua, việc mở rộng quy mô các mô ...
# 2  Bạn sẽ cầnChạy JobCài đặt SkillClaude CodeCode...
# 3  Cải thiện Hiệu suất & Thời gian chạy\nTái cấu ...
# 4  Hai tháng kể từ khi phát hành đợt đầu tiên của...

# %%
df.rename(columns={"Title": "title"}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    237 non-null    object
#  1   content  237 non-null    object
# dtypes: object(2)
# memory usage: 5.9+ KB

# %%
df[['title', 'content']] = df[['title', 'content']].replace('', np.nan)
df = df.dropna(subset=['title', 'content'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 237 entries, 0 to 236
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    237 non-null    object
#  1   content  237 non-null    object
# dtypes: object(2)
# memory usage: 5.6+ KB

# %%
df = df.assign(label="DEEP DIVE")

# %%
df.head()
# Out:
#                                                title  \
# 0  PRX Part 3 — Đào tạo một Text-to-Image Model t...
# 1       Mixture of Experts (MoEs) trong Transformers
# 2  Huấn luyện các mô hình AI với Unsloth và Huggi...
# 3  Transformers.js v4 Preview: Hiện đã có mặt trê...
# 4  Mô hình Holo2 mới của Công ty H dẫn đầu trong ...
#
#                                              content      label
# 0  Chào mừng trở lại 👋 Trong hai bài viết trước (...  DEEP DIVE
# 1  Trong vài năm qua, việc mở rộng quy mô các mô ...  DEEP DIVE
# 2  Bạn sẽ cầnChạy JobCài đặt SkillClaude CodeCode...  DEEP DIVE
# 3  Cải thiện Hiệu suất & Thời gian chạy\nTái cấu ...  DEEP DIVE
# 4  Hai tháng kể từ khi phát hành đợt đầu tiên của...  DEEP DIVE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 237 entries, 0 to 236
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    237 non-null    object
#  1   content  237 non-null    object
#  2   label    237 non-null    object
# dtypes: object(3)
# memory usage: 7.4+ KB

# %%
df.label.value_counts()
# Out:
# label
# DEEP DIVE    237
# Name: count, dtype: int64

# %%
df.to_csv("/home/binperdok/KLTN2026/Data/data_label_deepdive/final_09_03_2026.csv", index = False, encoding='utf-8-sig')
